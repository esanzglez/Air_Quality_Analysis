# %%
#importing all the modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sensor = pd.read_csv('sensor2.csv')

# %%
sensor.drop('Unnamed: 0',axis=1, inplace=True)

# %%
sensor.head()
# Out:
#                     dt    sensor         con        spl        date      time
# 0  2016-06-21 00:00:00  sensor_2  1691.99625  70.375943  2016-06-21  00:00:00
# 1  2016-06-21 04:00:00  sensor_2  2550.94500  72.334450  2016-06-21  04:00:00
# 2  2016-06-21 08:00:00  sensor_2  3088.82750  76.372047  2016-06-21  08:00:00
# 3  2016-06-21 12:00:00  sensor_2  2561.64625  77.571715  2016-06-21  12:00:00
# 4  2016-06-21 16:00:00  sensor_2  2721.79125  75.635837  2016-06-21  16:00:00

# %%
sensor[sensor.date=='2016-06-21']
# Out:
#                     dt    sensor         con        spl        date      time
# 0  2016-06-21 00:00:00  sensor_2  1691.99625  70.375943  2016-06-21  00:00:00
# 1  2016-06-21 04:00:00  sensor_2  2550.94500  72.334450  2016-06-21  04:00:00
# 2  2016-06-21 08:00:00  sensor_2  3088.82750  76.372047  2016-06-21  08:00:00
# 3  2016-06-21 12:00:00  sensor_2  2561.64625  77.571715  2016-06-21  12:00:00
# 4  2016-06-21 16:00:00  sensor_2  2721.79125  75.635837  2016-06-21  16:00:00
# 5  2016-06-21 20:00:00  sensor_2  2011.69375  72.578652  2016-06-21  20:00:00

# %%
sensor.con.plot(figsize=(10,10), color="IndianRed")
plt.xticks(rotation=75, fontsize=20)
plt.yticks(fontsize=20)
plt.ylim(-20, plt.ylim()[1])
plt.legend(loc='best',fontsize=20)
plt.xlabel("date", fontsize=20)
plt.ylabel("con", fontsize=20)

# %%
sensor.spl.plot(figsize=(10,10), color="IndianRed")
plt.xticks(rotation=75, fontsize=20)
plt.yticks(fontsize=20)
plt.ylim(-20, plt.ylim()[1])
plt.legend(loc='best',fontsize=20)
plt.xlabel("date", fontsize=20)
plt.ylabel("con", fontsize=20)

# %%
sensor_con = sensor[['dt', 'con']].groupby('dt').sum()
sensor_spl = sensor[['dt', 'spl']].groupby('dt').sum()

# %%
sensor_con.plot(figsize=(10,10), color="IndianRed")
plt.xticks(rotation=75, fontsize=20)
plt.yticks(fontsize=20)
plt.ylim(-20, plt.ylim()[1])
plt.legend(loc='best',fontsize=20)
plt.xlabel("date", fontsize=20)
plt.ylabel("con", fontsize=20)

# %%
sensor_spl.plot(figsize=(10,10), color="IndianRed")
plt.xticks(rotation=75, fontsize=20)
plt.yticks(fontsize=20)
plt.ylim(-20, plt.ylim()[1])
plt.legend(loc='best',fontsize=20)
plt.xlabel("Date", fontsize=20)
plt.ylabel("Noise Level", fontsize=20)

# %%
pd.stats.moments.rolling_mean(sensor.spl,6).plot()
# Out:
# C:\Users\enrique\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=6,center=False).mean()
#   if __name__ == '__main__':

# %%
pd.stats.moments.rolling_mean(sensor.con,6).plot()
# Out:
# C:\Users\enrique\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=6,center=False).mean()
#   if __name__ == '__main__':
